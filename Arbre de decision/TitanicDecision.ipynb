# %%
import numpy as np
import pandas as pd 
from sklearn import linear_model, metrics, tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('titanic.csv')

# %%
dataset.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
del dataset['PassengerId']
# del dataset['Name']
# del dataset['Ticket']

# %%
dataset.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch Cabin Embarked
# 0         0       3    1  22.0      1      0   NaN        S
# 1         1       1    0  38.0      1      0   C85        C
# 2         1       3    0  26.0      0      0   NaN        S
# 3         1       1    0  35.0      1      0  C123        S
# 4         0       3    1  35.0      0      0   NaN        S

# %%
sns.heatmap(dataset.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
dataset.replace({'Sex':{
    'female':0,
    'male':1
}}, inplace=True)

# %%
dataset.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch Cabin Embarked
# 0         0       3    1  22.0      1      0   NaN        S
# 1         1       1    0  38.0      1      0   C85        C
# 2         1       3    0  26.0      0      0   NaN        S
# 3         1       1    0  35.0      1      0  C123        S
# 4         0       3    1  35.0      0      0   NaN        S

# %%
dataset.replace({'Embarked':{
    'S':0,
    'C':1
}}, inplace=True)

# %%
dataset['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
dataset['Age'] = dataset['Age'].fillna(np.mean(dataset['Age']))

# %%
dataset
# Out:
#      Survived  Pclass  Sex        Age  SibSp  Parch Cabin Embarked  \
# 0           0       3    1  22.000000      1      0   NaN        0
# 1           1       1    0  38.000000      1      0   C85        1
# 2           1       3    0  26.000000      0      0   NaN        0
# 3           1       1    0  35.000000      1      0  C123        0
# 4           0       3    1  35.000000      0      0   NaN        0
# ..        ...     ...  ...        ...    ...    ...   ...      ...
# 886         0       2    1  27.000000      0      0   NaN        0
# 887         1       1    0  19.000000      0      0   B42        0
# 888         0       3    0  29.699118      1      2   NaN        0
# 889         1       1    1  26.000000      0      0  C148        1
# 890         0       3    1  32.000000      0      0   NaN        Q
#
#                                            Null values
# 0    <bound method Series.isna of 0      22.0\n1   ...
# ...

# %%
dataset['Null values'] = dataset['Cabin'].isna()

# %%
df_y = dataset['Survived']
df_x = dataset.drop('Survived', axis=1)

# %%
x_train, x_test, y_train, y_test = train_test_split()

# %%
reg = linear_model.LogisticRegression()
