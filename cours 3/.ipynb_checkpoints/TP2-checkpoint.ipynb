# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn import linear_model
from sklearn.model_selection import train_test_split 
from mpl_toolkits.mplot3d import Axes3D

# %%
data = pd.read_excel('data.xlsx')

# %%
data
# Out:
#     taille_en_pieds_carre  nb_chambres    prix
# 0                    2104            3  399900
# 1                    1600            3  329900
# 2                    2400            3  369000
# 3                    1416            2  232000
# 4                    3000            4  539900
# 5                    1985            4  299900
# 6                    1534            3  314900
# 7                    1427            3  198999
# 8                    1380            3  212000
# 9                    1494            3  242500
# 10                   1940            4  239999
# 11                   2000            3  347000
# 12                   1890            3  329999
# 13                   4478            5  699900
# 14                   1268            3  259900
# 15                   2300            4  449900
# 16                   1320            2  299900
# 17                   1236            3  199900
# 18                   2609            4  499998
# 19                   3031            4  599000
# 20                   1767            3  252900
# 21                   1888            2  255000
# 22                   1604            3  242900
# 23                   1962            4  259900
# 24                   3890            3  573900
# 25                   1100            3  249900
# 26                   1458            3  464500
# 27                   2526            3  469000
# 28                   2200            3  475000
# 29                   2637            3  299900
# 30                   1839            2  349900
# 31                   1000            1  169900
# 32                   2040            4  314900
# 33                   3137            3  579900
# 34                   1811            4  285900
# 35                   1437            3  249900
# 36                   1239            3  229900
# 37                   2132            4  345000
# 38                   4215            4  549000
# 39                   2162            4  287000
# 40                   1664            2  368500
# 41                   2238            3  329900
# 42                   2567            4  314000
# 43                   1200            3  299000
# 44                    852            2  179900
# 45                   1852            4  299900
# 46                   1203            3  239500

# %%
y = data['prix']

# %%
y
# Out:
# 0     399900
# 1     329900
# 2     369000
# 3     232000
# 4     539900
# 5     299900
# 6     314900
# 7     198999
# 8     212000
# 9     242500
# 10    239999
# 11    347000
# 12    329999
# 13    699900
# 14    259900
# 15    449900
# 16    299900
# 17    199900
# 18    499998
# 19    599000
# 20    252900
# 21    255000
# 22    242900
# 23    259900
# 24    573900
# 25    249900
# 26    464500
# 27    469000
# 28    475000
# 29    299900
# 30    349900
# 31    169900
# 32    314900
# 33    579900
# 34    285900
# 35    249900
# 36    229900
# 37    345000
# 38    549000
# 39    287000
# 40    368500
# 41    329900
# 42    314000
# 43    299000
# 44    179900
# 45    299900
# 46    239500
# Name: prix, dtype: int64

# %%
x = data[['taille_en_pieds_carre', 'nb_chambres']]

# %%
x
# Out:
#     taille_en_pieds_carre  nb_chambres
# 0                    2104            3
# 1                    1600            3
# 2                    2400            3
# 3                    1416            2
# 4                    3000            4
# 5                    1985            4
# 6                    1534            3
# 7                    1427            3
# 8                    1380            3
# 9                    1494            3
# 10                   1940            4
# 11                   2000            3
# 12                   1890            3
# 13                   4478            5
# 14                   1268            3
# 15                   2300            4
# 16                   1320            2
# 17                   1236            3
# 18                   2609            4
# 19                   3031            4
# 20                   1767            3
# 21                   1888            2
# 22                   1604            3
# 23                   1962            4
# 24                   3890            3
# 25                   1100            3
# 26                   1458            3
# 27                   2526            3
# 28                   2200            3
# 29                   2637            3
# 30                   1839            2
# 31                   1000            1
# 32                   2040            4
# 33                   3137            3
# 34                   1811            4
# 35                   1437            3
# 36                   1239            3
# 37                   2132            4
# 38                   4215            4
# 39                   2162            4
# 40                   1664            2
# 41                   2238            3
# 42                   2567            4
# 43                   1200            3
# 44                    852            2
# 45                   1852            4
# 46                   1203            3

# %%
graph = plt.figure()
ax = graph.add_subplot(111, projection='3d')
ax.scatter(data['taille_en_pieds_carre'], data['nb_chambres'], data['prix'])
plt.show()

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
x_train
# Out:
#     taille_en_pieds_carre  nb_chambres
# 0                    2104            3
# 43                   1200            3
# 38                   4215            4
# 28                   2200            3
# 6                    1534            3
# 41                   2238            3
# 2                    2400            3
# 13                   4478            5
# 30                   1839            2
# 12                   1890            3
# 3                    1416            2
# 16                   1320            2
# 10                   1940            4
# 33                   3137            3
# 21                   1888            2
# 45                   1852            4
# 26                   1458            3
# 23                   1962            4
# 11                   2000            3
# 25                   1100            3
# 1                    1600            3
# 29                   2637            3
# 17                   1236            3
# 4                    3000            4
# 24                   3890            3
# 18                   2609            4
# 27                   2526            3
# 37                   2132            4
# 32                   2040            4
# 46                   1203            3
# 15                   2300            4
# 40                   1664            2
# 7                    1427            3
# 31                   1000            1
# 39                   2162            4
# 5                    1985            4
# 44                    852            2

# %%
x_test
# Out:
#     taille_en_pieds_carre  nb_chambres
# 22                   1604            3
# 8                    1380            3
# 34                   1811            4
# 42                   2567            4
# 19                   3031            4
# 20                   1767            3
# 36                   1239            3
# 35                   1437            3
# 9                    1494            3
# 14                   1268            3

# %%
y_train
# Out:
# 0     399900
# 43    299000
# 38    549000
# 28    475000
# 6     314900
# 41    329900
# 2     369000
# 13    699900
# 30    349900
# 12    329999
# 3     232000
# 16    299900
# 10    239999
# 33    579900
# 21    255000
# 45    299900
# 26    464500
# 23    259900
# 11    347000
# 25    249900
# 1     329900
# 29    299900
# 17    199900
# 4     539900
# 24    573900
# 18    499998
# 27    469000
# 37    345000
# 32    314900
# 46    239500
# 15    449900
# 40    368500
# 7     198999
# 31    169900
# 39    287000
# 5     299900
# 44    179900
# Name: prix, dtype: int64

# %%
y_test
# Out:
# 22    242900
# 8     212000
# 34    285900
# 42    314000
# 19    599000
# 20    252900
# 36    229900
# 35    249900
# 9     242500
# 14    259900
# Name: prix, dtype: int64

# %%
reg = linear_model.LinearRegression()

# %%
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
predict = reg.predict(x_test)

# %%
predict
# Out:
# array([294498.66243283, 265130.855361  , 316430.17533168, 415546.52419912,
#        476379.83884792, 315868.98632885, 246644.86965953, 272603.91341052,
#        280076.97146005, 250446.95182508])

# %%
graph = plt.figure()
ax = graph.add_subplot(projection='3d')
ax.scatter(data['taille_en_pieds_carre'], data['nb_chambres'], data['prix'])
ax.plot(x_test['taille_en_pieds_carre'], x_test['nb_chambres'], predict)
plt.show()

# %%
print(reg.predict(np.array([[420, 5]]))) #predicting from trained model
# Out:
# [128853.85028058]
# C:\Users\ghsts\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
